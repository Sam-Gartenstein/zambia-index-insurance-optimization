# %% [markdown]
# # Zambia Insurance Optimization
#
# The goal of this project is to reduce basis risk in weather insurance contracts, building upon [earlier work](https://github.com/Sam-Gartenstein/zambia-drought-analysis) where we introduced the Payout Balance Index (PBI). Rather than relying on K-means clustering, we calculate the PBI using Zambia’s two administrative levels along with camps developed by (name), and estimate the monetary value of insurance forgone due to mismatches between payouts and actual conditions. In addition, we consider the perspective of a decision-maker, who must weigh the administrative burden of monitoring each zone. Framing the problem as a constrained optimization, we seek to minimize basis risk (equivalently, maximize the number of farmers protected) while simultaneously reducing administrative complexity.

# %%
'''
Please keep commented. This is not necessary for the code below to work.
'''

import pyproj

path = "/Users/samuelgartenstein/anaconda3/envs/my_project_env/share/proj"
pyproj.datadir.set_data_dir(path)
print("PROJ data directory has been successfully set.")
# Out:
# PROJ data directory has been successfully set.

# %%
# Core Python libraries
import numpy as np
import pandas as pd

# Geospatial analysis libraries
import geopandas as gpd
import ee
import geemap
import folium

# Plotting libraries
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import plotly.graph_objects as go

# Custom utility functions
from utils.preprocessing import (
    summarize_admin_level,
    load_fao_gaul_data,
    spatial_join_by_intersects,
    long_format_precipitation,
    compute_mean_precip
) 

from utils.drought_payout_anlaysis import (
    assign_drought_indicator,
    count_unique_drought_years,
    plot_drought_heatmap_interactive,
    plot_drought_heatmap_static,
    summarize_drought_by_cluster,
    plot_drought_percentage_heatmap_interactive,
    plot_drought_percentage_heatmap_static, 
    compute_payout_balance_index,
    plot_forgone_by_zones,
    benefit_changes
)

# %% [markdown]
# ## Initialize Earth Engine API
#
# Authenticate and initialize the Earth Engine API for this notebook. Please replace with your own project ID when running.

# %%
# Authenticate Earth Engine API
ee.Authenticate()

# Initialize the Earth Engine API
ee.Initialize(project='ee-sg4283')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_7TDKVSyKvBdmMqW?ref=4i2o6

# %% [markdown]
# ## Reading in Data
#
# We read in the Zambia Admin-1 (provinces), Admin-2 (districts), and Camp shapefiles using GeoPandas, ensuring a common CRS (EPSG:4326) and standardizing key columns for easier merging and analysis. This provides consistent geospatial layers for linking with rainfall and other datasets.

# %% [markdown]
# ### Administrative 1

# %%
# Load admin 1 (provinces)
zambia_gdf_1 = gpd.read_file("data/zambia_shapefiles/zmb_admbnda_adm1_dmmu_20201124.shp")
zambia_gdf_1 = zambia_gdf_1.rename(columns={"ADM1_EN": "ADM1_NAME"})
zambia_gdf_1
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Shape_Leng  Shape_Area      ADM1_NAME ADM1_PCODE ADM1_REF ADM1ALT1EN  \
# 0   25.222638    9.141987        Central       ZM10     None       None
# 1    8.863299    2.588911     Copperbelt       ZM20     None       None
# ...

# %%
# Check the overall shape of the Admin-1 GeoDataFrame
print("GeoDataFrame shape:", zambia_gdf_1.shape)

# Count the number of unique province names (ADM1_NAME)
num_provinces = zambia_gdf_1['ADM1_NAME'].nunique()
print("Number of unique ADM1_NAME values (provinces):", num_provinces)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# GeoDataFrame shape: (10, 13)
# Number of unique ADM1_NAME values (provinces): 10

# %%
# Plot the shapefile
zambia_gdf_1.plot(figsize=(10, 10), edgecolor='black')
plt.title("Zambia 1 Administrative Zones")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Administrative 2

# %%
# Load admin 1 (provinces)
zambia_gdf_2 = gpd.read_file("data/zambia_shapefiles/zmb_admbnda_adm2_dmmu_20201124.shp")
zambia_gdf_2 = zambia_gdf_2.rename(columns={"ADM2_EN": "ADM2_NAME"})
zambia_gdf_2.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Shape_Leng  Shape_Area     ADM2_NAME ADM2_PCODE ADM2_REF ADM2ALT1EN  \
# 0    4.718827    0.747446      Chibombo     ZM1001     None       None
# 1    3.661521    0.442670      Chisamba     ZM1007     None       None
# ...

# %%
# Check the overall shape of the Admin-2 GeoDataFrame
print("GeoDataFrame shape:", zambia_gdf_2.shape)

# Count the number of unique district names (ADM2_NAME)
num_districts = zambia_gdf_2['ADM2_NAME'].nunique()
print("Number of unique ADM2_NAME values (districts):", num_districts)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# GeoDataFrame shape: (115, 15)
# Number of unique ADM2_NAME values (districts): 115

# %%
# Plot the shapefile
zambia_gdf_2.plot(figsize=(10, 10), edgecolor='black')
plt.title("Zambia 2 Administrative Zones")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Administraitve 3 (Camps)

# %%
# Load Zambia's third administrative level (camps) from shapefile
shapefile_path = (
    "data/boundaries/Agricultural_blocks_and_camps_062022_Version_01/"
    "Agricultural_blocks_and_camps_062022_Version_01.shp"
)

# Read shapefile into GeoDataFrame
zambia_gdf_3 = gpd.read_file(shapefile_path)

# Preview the first 10 rows
zambia_gdf_3.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     Fid    Province    District        Block           Camp  Area_Sq_km  \
# 0   1.0  Copperbelt    Mufulira      Murundu        Mokambo        59.0
# 1   2.0  Copperbelt   Kalulushi        Chati  Chati Central       209.0
# ...

# %%
# Plot the shapefile
zambia_gdf_3.plot(figsize=(10, 10), edgecolor='black')
plt.title("Agricultural Blocks and Camps")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Examining Camp Properties
#
# Since the camp data is a bit messy, I am going to examine

# %%
# Shape of the camps GeoDataFrame
print(f"Dataset dimensions (rows, columns): {zambia_gdf_3.shape}")

# Number of unique camps
num_unique_camps = zambia_gdf_3["Camp"].nunique()
print(f"Number of unique camps: {num_unique_camps}")

# Count of missing values in the Camp column
num_missing_camps = zambia_gdf_3["Camp"].isna().sum()
print(f"Number of missing camp entries: {num_missing_camps}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Dataset dimensions (rows, columns): (2648, 14)
# Number of unique camps: 2447
# Number of missing camp entries: 27

# %% [markdown]
# #### Anaylsis
#
# There are 2648 rows, and 2447 unique camps. Furthermore, there are only 27 camp names that are missing. As a result, there are most likely repeat of names. This is examined in the line directly below.

# %%
# Count occurrences of each camp, only show those > 1
print(zambia_gdf_3["Camp"].value_counts().sort_values(ascending=False)[lambda x: x > 1])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Camp
# Kawama         6
# Chisanga       4
# Mushingashi    4
# Kazembe        4
# Bombwe         3
#               ..
# Kakoma         2
# Kasongole      2
# Muyembe        2
# Kafubashi      2
# Chikowa        2
# ...

# %% [markdown]
# ### Assigning Names for Missing Camps
#
# Repeated camp names are not problematic for the analysis, but missing values are. To address this, I assign placeholder names (e.g., `Camp_1`, `Camp_2`, …) to all null entries in the `Camp` field. This ensures every record has an identifiable camp name and avoids issues in downstream analysis.

# %%
# Find rows where "Camp" is missing
missing_camp_mask = zambia_gdf_3["Camp"].isna()
num_missing = missing_camp_mask.sum()
print(f"Number of missing camp entries: {num_missing}")

# Generate new names: Camp 1, Camp 2, ...
new_camp_names = [f"Camp_{i+1}" for i in range(num_missing)]

# Assign new names to missing entries
zambia_gdf_3.loc[missing_camp_mask, "Camp"] = new_camp_names

# Confirm number of unique camps after filling
num_unique_camps = zambia_gdf_3["Camp"].nunique()
print(f"Number of unique camps after assignment: {num_unique_camps}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of missing camp entries: 27
# Number of unique camps after assignment: 2474

# %% [markdown]
# ## Loading Seasonal Precipitation
#
# Now, we can load the seasonal precipitation created in [Loading and Preprocessing Pixels](https://github.com/Sam-Gartenstein/zambia-index-insurance-optimization/blob/main/Loading%20and%20Preprocessing%20Pixels.ipynb).

# %%
zambia_seasonal_precip = gpd.read_feather("data/precipitation data/zambia_seasonal_precipitation.feather")
zambia_seasonal_precip.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       Pixel_ID        lat        lon                    geometry        1982  \
# 0      Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  225.556387
# ...

# %%
zambia_seasonal_precip.geometry.plot(figsize=(10, 10), markersize=1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Axes: >

# %% [markdown]
# ## Assigning Pixels to Boundaries
#
# We assign each rainfall pixel to its corresponding administrative zone at all three levels (ADM1, ADM2, and camps). This step enables aggregation of pixel-level metrics into zone-level summaries for analysis. In addition, we verify that every pixel is assigned to a zone to ensure there are no missing values.

# %% [markdown]
# ### Administrative 1

# %%
zambia_seasonal_precip_1 = spatial_join_by_intersects(zambia_seasonal_precip, zambia_gdf_1)
zambia_seasonal_precip_1.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        Pixel_ID        lat        lon                    geometry        1982  \
# 0       Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  225.556387
# ...

# %%
# Count the number of missing (NaN) values in the 'Camp' column
zambia_seasonal_precip_1['ADM1_NAME'].isna().sum()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 69

# %% [markdown]
# ### Administrative 2

# %%
zambia_seasonal_precip_2 = spatial_join_by_intersects(zambia_seasonal_precip, zambia_gdf_2, admin_col="ADM2_NAME")
zambia_seasonal_precip_2.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        Pixel_ID        lat        lon                    geometry        1982  \
# 0       Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  225.556387
# ...

# %%
# Count the number of missing (NaN) values in the 'Camp' column
zambia_seasonal_precip_2['ADM2_NAME'].isna().sum()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 69

# %% [markdown]
# ### Administrative 3

# %%
zambia_seasonal_precip_3 = spatial_join_by_intersects(zambia_seasonal_precip, zambia_gdf_3, admin_col="Camp")
zambia_seasonal_precip_3.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        Pixel_ID        lat        lon                    geometry        1982  \
# 0       Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  225.556387
# ...

# %%
# Count the number of missing (NaN) values in the 'Camp' column
zambia_seasonal_precip_3['Camp'].isna().sum()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 37

# %% [markdown]
# ## Mapping Missing Pixel Values
#
# The pixel data collected from GEE was extracted using FAO GAUL 2015 boundary definitions. Since the most up-to-date boundaries differ slightly in shape, some pixels may fall outside the newer administrative limits. Below, I analyze missing pixel data for each district and camp.

# %%
def plot_missing_points(points_gdf, boundary_gdf, label_col, 
                        title=None, marker_size=12,
                        boundary_kwargs=None, point_kwargs=None):
    """
    Plot features in `points_gdf` where `label_col` is missing, overlaid on `boundary_gdf`.

    - Auto-aligns CRS by reprojecting points to boundary CRS if needed (does NOT force EPSG:4326).
    - Returns (missing_points_gdf, ax) for further use.
    """
    boundary_kwargs = boundary_kwargs or {"color": "black", "linewidth": 1}
    point_kwargs = point_kwargs or {"color": "red", "markersize": marker_size, "label": f"Missing {label_col}"}

    # 1) Filter rows with missing label
    missing = points_gdf[points_gdf[label_col].isna()].copy()

    # 2) Align CRS (only if different)
    if boundary_gdf.crs is None and missing.crs is None:
        # No CRS info anywhere—plot will still work, but spatial alignment isn't guaranteed
        pass
    elif boundary_gdf.crs is not None and (missing.crs is None or missing.crs != boundary_gdf.crs):
        missing = missing.to_crs(boundary_gdf.crs)

    # 3) Plot
    fig, ax = plt.subplots(figsize=(10, 10))
    boundary_gdf.boundary.plot(ax=ax, **boundary_kwargs)
    if len(missing):
        missing.plot(ax=ax, **point_kwargs)
        ax.legend()
    ax.set_title(title or f"Locations with Missing '{label_col}'", fontsize=14)
    plt.show()

    return missing, ax
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Admin-1 example
missing_adm1, ax = plot_missing_points(
    points_gdf=zambia_seasonal_precip_1,
    boundary_gdf=zambia_gdf_1,            # admin1 boundary layer
    label_col="ADM1_NAME",
    title="Zambia: Locations with Missing 'ADM1_NAME'"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Admin-1 example
missing_adm2, ax = plot_missing_points(
    points_gdf=zambia_seasonal_precip_2,
    boundary_gdf=zambia_gdf_2,            # admin2 boundary layer
    label_col="ADM2_NAME",
    title="Zambia: Locations with Missing 'ADM2_NAME'"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Camps example
missing_camp, ax = plot_missing_points(
    points_gdf=zambia_seasonal_precip_3,
    boundary_gdf=zambia_gdf_3,            # camps boundary layer
    label_col="Camp",
    title="Zambia: Locations with Missing 'Camp'"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Insights
#
# For the Administrative 1 and 2 zones, 69 pixels are missing, while for the camps, 37 pixels are missing. All of these missing pixels are located along the outer borders, which reflects differences between the FAO GAUL 2015 boundaries and the updated shapefiles. Because the number of missing pixels is very small relative to the total dataset, they will be dropped, as their exclusion is unlikely to significantly affect the analysis.

# %%
# Drop missing rows
zambia_seasonal_precip_1 = zambia_seasonal_precip_1.dropna(subset=["ADM1_NAME"])
print("Admin-1 precip shape:", zambia_seasonal_precip_1.shape)

zambia_seasonal_precip_2 = zambia_seasonal_precip_2.dropna(subset=["ADM2_NAME"])
print("Admin-2 precip shape:", zambia_seasonal_precip_2.shape)

zambia_seasonal_precip_3 = zambia_seasonal_precip_3.dropna(subset=["Camp"])
print("Camp precip shape:", zambia_seasonal_precip_3.shape)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Admin-1 precip shape: (25022, 48)
# Admin-2 precip shape: (25022, 48)
# Camp precip shape: (25054, 48)

# %% [markdown]
# ## Additional Preprocessing
#
# The end goal is caluclate the payout balance metric. However, we must do some additional preprocessing.

# %% [markdown]
# ### Converting Data from Wide to Long Format
#
# The next step is to reshape each administrative boundary dataset from wide format to long format. This transformation is necessary to enable consistent spatial aggregation across pixels at each level (ADM1, ADM2, and camps) and to prepare the data for further analyses.

# %% [markdown]
# #### Administrative 1

# %%
zambia_long_gdf_1 = long_format_precipitation(zambia_seasonal_precip_1, cluster_columns=["ADM1_NAME"])
zambia_long_gdf_1.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pixel_ID        lat        lon                    geometry ADM1_NAME  \
# 0   Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  Southern
# 1   Pixel 2 -18.024985  26.674978  POINT (26.67498 -18.02499)  Southern
# ...

# %% [markdown]
# #### Administrative 2

# %%
zambia_long_gdf_2 = long_format_precipitation(zambia_seasonal_precip_2, cluster_columns=["ADM2_NAME"])
zambia_long_gdf_2.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pixel_ID        lat        lon                    geometry  ADM2_NAME  \
# 0   Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)      Zimba
# 1   Pixel 2 -18.024985  26.674978  POINT (26.67498 -18.02499)      Zimba
# ...

# %% [markdown]
# #### Administrative 3

# %%
zambia_long_gdf_3 = long_format_precipitation(zambia_seasonal_precip_3, cluster_columns=["Camp"])
zambia_long_gdf_3.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pixel_ID        lat        lon                    geometry      Camp  \
# 0   Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  Kamukeza
# 1   Pixel 2 -18.024985  26.674978  POINT (26.67498 -18.02499)  Kamukeza
# ...

# %% [markdown]
# ### Spatial Aggregation to Administrative District
#
# We now aggregate pixel-level values to the district level by taking the mean of all pixels within each district for every year. This approach mirrors Google Earth Engine’s method for spatial aggregation when using the API, ensuring consistency between pixel-level data and administrative boundaries.

# %%
'''
Move to script
'''

def compute_mean_precip(df, group_cols, value_col="precipitation"):
    """
    Groups the DataFrame by specified columns and computes the mean of the value column.

    Parameters:
    - df (DataFrame): Input DataFrame.
    - group_cols (list): List of columns to group by.
    - value_col (str): Name of the column to average.

    Returns:
    - DataFrame with group means.
    """
    return df.groupby(group_cols)[value_col].mean().reset_index()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Administrative 1

# %%
mean_precip_by_admin_1_season = compute_mean_precip(zambia_long_gdf_1, ["ADM1_NAME", "agricultural_season"])
mean_precip_by_admin_1_season.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   ADM1_NAME  agricultural_season  precipitation
# 0   Central                 1982     715.838989
# 1   Central                 1983     729.742448
# 2   Central                 1984     751.203404
# ...

# %% [markdown]
# #### Administrative 2

# %%
mean_precip_by_admin_2_season = compute_mean_precip(zambia_long_gdf_2, ["ADM2_NAME", "agricultural_season"])
mean_precip_by_admin_2_season.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   ADM2_NAME  agricultural_season  precipitation
# 0   Chadiza                 1982     796.034920
# 1   Chadiza                 1983     771.864512
# 2   Chadiza                 1984     774.262436
# ...

# %% [markdown]
# #### Administrative 3

# %%
mean_precip_by_admin_3_season = compute_mean_precip(zambia_long_gdf_3, ["Camp", "agricultural_season"])
mean_precip_by_admin_3_season.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      Camp  agricultural_season  precipitation
# 0  Adonsi                 1982     340.823207
# 1  Adonsi                 1983     476.650080
# 2  Adonsi                 1984     546.149077
# ...

# %% [markdown]
# ### Adding the Drought Indicator
#
# Next, we introduce a drought indicator. A district or camp is considered to be in drought if annual rainfall falls below the historical 20th percentile for the sample period. Given the 44-year record, this threshold should identify approximately 9 unique drought years. To validate, we check the number of unique drought years in the dataset, which should equal 9.

# %% [markdown]
# #### Administrative 1

# %%
mean_precip_by_admin_1_season = assign_drought_indicator(mean_precip_by_admin_1_season, "ADM1_NAME")
mean_precip_by_admin_1_season.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   ADM1_NAME  agricultural_season  precipitation  drought_indicator
# 0   Central                 1982     715.838989                  1
# 1   Central                 1983     729.742448                  0
# ...

# %%
count_unique_drought_years(mean_precip_by_admin_1_season, admin_col="ADM1_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [9]

# %% [markdown]
# #### Administrative 2

# %%
mean_precip_by_admin_2_season = assign_drought_indicator(mean_precip_by_admin_2_season, "ADM2_NAME")
mean_precip_by_admin_2_season.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   ADM2_NAME  agricultural_season  precipitation  drought_indicator
# 0   Chadiza                 1982     796.034920                  0
# 1   Chadiza                 1983     771.864512                  1
# ...

# %%
count_unique_drought_years(mean_precip_by_admin_2_season, admin_col="ADM2_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [9]

# %% [markdown]
# #### Administrative 3

# %%
mean_precip_by_admin_3_season = assign_drought_indicator(mean_precip_by_admin_3_season, "Camp")
mean_precip_by_admin_3_season.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      Camp  agricultural_season  precipitation  drought_indicator
# 0  Adonsi                 1982     340.823207                  1
# 1  Adonsi                 1983     476.650080                  1
# ...

# %%
count_unique_drought_years(mean_precip_by_admin_3_season, admin_col="Camp")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [9]

# %% [markdown]
# ### Drought Heatmaps
#
# The following heatmaps show drought occurrence across years and administrative districts for each level of analysis. Cells indicate whether a district experienced drought (red) or non-drought (green) conditions during the sample period.
#
# **Note**: The interactive heatmap code is currently commented out for readability.
# Uncomment it to explore the interactive version, which includes hover details such as precipitation values.

# %% [markdown]
# #### Administrative 1

# %%
#plot_drought_heatmap_interactive(mean_precip_by_admin_1_season, "ADM1_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
plot_drought_heatmap_static(mean_precip_by_admin_1_season, "ADM1_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Administrative 2

# %%
plot_drought_heatmap_static(mean_precip_by_admin_2_season, "ADM2_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#plot_drought_heatmap_interactive(mean_precip_by_admin_2_season, "ADM2_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Administrative 3
#
# Because of the large number of camps, only an **interactive heatmap** is provided to explore droughts across camps and years. Use the zoom and pan controls for better readability and to focus on specific time periods or camp clusters.

# %%
#plot_drought_heatmap_interactive(mean_precip_by_admin_3_season, "Camp")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Within-Cluster (Administrative District) Drought Variation
#
# To better understand drought distribution within each administrative district, I will analyze the number of pixels experiencing drought in each zone. This will help determine whether drought affects the entire district or only specific areas, inidicating potential basis risk.
#
# ### Steps:
#
# 1. **Create an agricultural season variable** to align all data with the relevant growing season.
# 2. **Aggregate pixel-level data** to the agricultural season for consistency in analysis.
# 3. **Assign a drought indicator to each pixel** based on whether it falls within the lowest 20% of rainfall seasons.
# 4. **Calculate the drought percentage** for each administrative district in each season:
#
# $$
# \text{Drought Percentage} = \left( \frac{\text{Number of Pixels in Drought}}{\text{Total Pixels in District}} \right) \times 100
# $$
#
# This approach will reveal spatial drought variations within each district, providing insights into localized drought intensity and improving climate risk assessment

# %%
'''
Make independent copies of the long-format precipitation data
for each administrative level to avoid modifying the originals.
'''

seasonal_precip_pixel_1 = zambia_long_gdf_1.copy() 

seasonal_precip_pixel_2 = zambia_long_gdf_2.copy() 

seasonal_precip_pixel_3 = zambia_long_gdf_3.copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Drought Indicator for each Pixel
#
# Next, we add a drought indicator **per pixel** (rather than per district). This lets us compute, for each district or camp, the **percentage of pixels in drought** during a given year/season—providing a finer-grained view of spatial drought intensity.

# %% [markdown]
# #### Administrative 1

# %%
seasonal_precip_pixel_1 = assign_drought_indicator(seasonal_precip_pixel_1, "Pixel_ID")
seasonal_precip_pixel_1.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pixel_ID        lat        lon                    geometry ADM1_NAME  \
# 0   Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  Southern
# 1   Pixel 2 -18.024985  26.674978  POINT (26.67498 -18.02499)  Southern
# ...

# %% [markdown]
# #### Administrative 2

# %%
seasonal_precip_pixel_2 = assign_drought_indicator(seasonal_precip_pixel_2, "Pixel_ID")
seasonal_precip_pixel_2.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pixel_ID        lat        lon                    geometry  ADM2_NAME  \
# 0   Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)      Zimba
# 1   Pixel 2 -18.024985  26.674978  POINT (26.67498 -18.02499)      Zimba
# ...

# %% [markdown]
# #### Administrative 3

# %%
seasonal_precip_pixel_3 = assign_drought_indicator(seasonal_precip_pixel_3, "Pixel_ID")
seasonal_precip_pixel_3.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pixel_ID        lat        lon                    geometry      Camp  \
# 0   Pixel 1 -18.024985  26.624978  POINT (26.62498 -18.02499)  Kamukeza
# 1   Pixel 2 -18.024985  26.674978  POINT (26.67498 -18.02499)  Kamukeza
# ...

# %% [markdown]
# ### Calculating Percentage of Pixels Experiencing Drought
#
# We now calculate the percentage of pixels experiencing drought in each administrative district or camp for a given year. This metric is essential for constructing the **Payout Balance Index (PBI)**, as it captures how widespread drought conditions are within each zone and ensures payouts are aligned with localized drought severity.

# %% [markdown]
# #### Administrative 1

# %%
seasonal_precip_pixel_1 = summarize_drought_by_cluster(seasonal_precip_pixel_1, "ADM1_NAME")
seasonal_precip_pixel_1.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   ADM1_NAME  agricultural_season  total_pixels  drought_pixels  \
# 0   Central                 1982          3674            1782
# 1   Central                 1983          3674            1572
# ...

# %% [markdown]
# #### Administrative 2

# %%
seasonal_precip_pixel_2 = summarize_drought_by_cluster(seasonal_precip_pixel_2, "ADM2_NAME")
seasonal_precip_pixel_2.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   ADM2_NAME  agricultural_season  total_pixels  drought_pixels  \
# 0   Chadiza                 1982            51               0
# 1   Chadiza                 1983            51              19
# ...

# %% [markdown]
# #### Administrative 3

# %%
seasonal_precip_pixel_3 = summarize_drought_by_cluster(seasonal_precip_pixel_3, "Camp")
seasonal_precip_pixel_3.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      Camp  agricultural_season  total_pixels  drought_pixels  \
# 0  Adonsi                 1982             4               4
# 1  Adonsi                 1983             4               4
# ...

# %% [markdown]
# ### Plotting Drought Percentage by District or Camp
#
# The plots below show the percentage of pixels in each district or camp experiencing drought in a given year. This visualization helps illustrate how droughts vary in both intensity and frequency across different administrative boundaries over time. Like the drought heat maps, the interactive maps are commented out, and there is no static map for the camps.

# %% [markdown]
# #### Administrative 1

# %%
plot_drought_percentage_heatmap_static(seasonal_precip_pixel_1, "ADM1_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#plot_drought_percentage_heatmap_interactive(seasonal_precip_pixel_1, "ADM1_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Administrative 2

# %%
plot_drought_percentage_heatmap_static(seasonal_precip_pixel_2, "ADM2_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#plot_drought_percentage_heatmap_interactive(seasonal_precip_pixel_2, "ADM2_NAME")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Administrative 3

# %%
#plot_drought_percentage_heatmap_interactive(seasonal_precip_pixel_3, "Camp")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Payout Balance Metric
#
# To evaluate how well the clustering minimizes **basis risk**, we first compute the **absolute deviation** from a 50% payout rate for each cluster-year pair:
#
# $$
# D_t^k = |P_t^k - 50|
# $$
#
# Where:
#
# - $P_t^k$ = Percentage of pixels receiving a payout in **cluster** $k$ during **year** $t$
# - $D_t^k$ = Absolute deviation from the 50% balance point — **higher values indicate greater basis risk**
#
# ---
#
# ### Payout Balance Index (PBI)
#
# We then transform this deviation into a **Payout Balance Index (PBI)** scaled between 0 and 100:
#
# $$
# \text{PBI}_{t,k} = \left(1 - \frac{D_t^k}{50} \right) \times 100
# $$
#
# - A value of **100** means perfect balance: all or none of the farmers in the cluster received payouts
# - A value of **0** indicates a 50/50 split — the **worst-case scenario** for basis risk
#
# ---
#
# ### Overall Clustering Quality
#
# To assess clustering quality across the entire dataset, we compute the **average PBI**:
#
# $$
# \text{PBI}_{\text{avg}} = \frac{1}{N} \sum_{t,k} \text{PBI}_{t,k}
# $$
#
# Where $N$ is the total number of (year × cluster) combinations.
#
# ---
#
# ### Basis Risk Interpretation
#
# - A **PBI close to 100** reflects **low basis risk**: clusters are internally consistent — farmers in the same area experience similar insurance outcomes
# - A **PBI near 0** reflects **high basis risk**: payout decisions vary significantly within clusters, indicating poor targeting
#
# This index provides a **clear, interpretable, and policy-relevant** measure of how well your spatial clustering aligns with actual drought impact.

# %% [markdown]
# #### Administrative 1

# %%
seasonal_precip_pixel_1 = compute_payout_balance_index(seasonal_precip_pixel_1)

payout_score_admin_1 = seasonal_precip_pixel_1["payout_balance_index"].mean()
print(f"Payout Balance Score Administratvie 1 Zones: {payout_score_admin_1:.2f}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Payout Balance Score Administratvie 1 Zones: 80.30

# %% [markdown]
# #### Administrative 2

# %%
seasonal_precip_pixel_2 = compute_payout_balance_index(seasonal_precip_pixel_2)

payout_score_admin_2 = seasonal_precip_pixel_2["payout_balance_index"].mean()
print(f"Payout Balance Score Administratvie 2 Zones: {payout_score_admin_2:.2f}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Payout Balance Score Administratvie 2 Zones: 89.21

# %% [markdown]
# #### Administrative 3

# %%
seasonal_precip_pixel_3 = compute_payout_balance_index(seasonal_precip_pixel_3)

payout_score_admin_3 = seasonal_precip_pixel_3["payout_balance_index"].mean()
print(f"Payout Balance Score Camps: {payout_score_admin_3:.2f}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Payout Balance Score Camps: 95.01

# %% [markdown]
# ## Forgone Payouts
#
# The next step is to calculate **forgone payouts**, which arise from **basis risk**.
# The **Payout Balance Index (PBI)** is designed to capture both dimensions of basis risk:
#
# - **Overpayments** — payouts made when they should not have been, and
# - **Underpayments** — payouts missed when they should have been triggered.
#
# Thus, the share of payouts not aligned with actual drought outcomes is represented by:
#
# $$
# 1 - \text{PBI}
# $$
#
# The **forgone payout** is then computed as:
#
# $$
# \text{Forgone Payout} =
# (\text{Payout Value}) \times (1 - \text{PBI}) \times (\text{Number of Pixels Per Zone})
# $$
#
# ### Parameters and Assumptions
#
# - **Payout Value**: assumed to be **1600 Kwacha** (≈ \$68).
#   - This figure is derived by dividing the total payout of **800 million Kwacha** by **500,071 smallholder farmers** who received payments for climate-related losses ([Pula Advisors, 2022](https://www.pula-advisors.com/post/zambia-s-largest-crop-index-insurance-payout-marks-historic-milestone-for-smallholder-farmers)).
#
# - **Number of Pixels**:
#   - ADM1 and ADM2 → **25,022 pixels**
#   - ADM3 (camps) → **25,054 pixels**
#
# - **Key Assumption**: each pixel represents an individual farmer, and farmers are assumed to be evenly distributed geographically.

# %%
# Define base payout and total number of pixels at each administrative level

payout_value = 1600        # Insurance payout value (currency units, e.g., ZMW)

admin_1_pixels = 25022     # Total number of pixels aggregated at Admin Level 1 (provinces/districts)
admin_2_pixels = 25022     # Total number of pixels aggregated at Admin Level 2 (sub-districts/wards)
admin_3_pixels = 25054     # Total number of pixels aggregated at Admin Level 3 (camps)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Administrative 1

# %%
# Administrative 1 forgone payments
admin_1_fp = (payout_value) * (1 - (payout_score_admin_1/100)) * (admin_1_pixels) 
print(f"Administrative 1 forgone payments: {admin_1_fp:.2f} kwacha")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Administrative 1 forgone payments: 7887800.10 kwacha

# %% [markdown]
# ### Administrative 2

# %%
# Administrative 2 forgone payments
admin_2_fp = (payout_value) * (1 - (payout_score_admin_2/100)) * (admin_2_pixels) 
print(f"Administrative 2 forgone payments: {admin_2_fp:.2f} kwacha")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Administrative 2 forgone payments: 4321774.40 kwacha

# %% [markdown]
# ### Administrative 3

# %%
# Administrative 3 forgone payments
admin_3_fp = (payout_value) * (1 - (payout_score_admin_3/100)) * (admin_3_pixels) 
print(f"Administrative 3 forgone payments: {admin_3_fp:.2f} kwacha")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Administrative 3 forgone payments: 2000546.91 kwacha

# %% [markdown]
# ### Forgone Payments vs Number of Zones

# %%
plot_forgone_by_zones(
    zones_to_fp={
        num_provinces:    admin_1_fp,
        num_districts:    admin_2_fp,
        num_unique_camps: admin_3_fp,
    },
    annotate_offsets=[(24, -6), (22, 0), (-6, 10)],  # per-point (dx, dy) in points
    annotate_ha="center",
    annotate_va="bottom",
);
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Analysis
#
# The plot above shows that the number of forgone payments decreases by 45% when moving from Administrative 1 to Administrative 2 districts. In addition, shifting from Administrative 2 to camps results in a further 54% decrease in forgone payments.

# %% [markdown]
# ## K-Means Analysis
#
# In the K-Means Clustering Analysis Notebook (put in link), we found that Payout Balance Index is 84.39%, and the forgone payment totalled around 6.25 million kwacha. We can add this to the plot.

# %%
num_clusters = 29
clusters_fp = 6249903.98
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
plot_forgone_by_zones(
    {
    num_provinces: admin_1_fp,
    num_districts: admin_2_fp,
    num_unique_camps: admin_3_fp,
    num_clusters: clusters_fp
},
    annotate_offsets=[(0, -19), (24, -5), (23, -6), (-17,-13)],  # per-point (dx, dy) in points
    annotate_ha="center",
    annotate_va="bottom",
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# (<Figure size 800x500 with 1 Axes>,
#  <Axes: title={'center': 'Forgone Payments by Number of Zones'}, xlabel='Number of zones', ylabel='Forgone Payments'>)

# %% [markdown]
# ## Marginal Benefit per Zone Change
#
# Increasing the number of zones reduces forgone payments, but this does not automatically imply greater implementation efficiency. As zone counts grow, diminishing returns may arise—each added zone tends to yield a smaller improvement.
#
# To quantify the marginal effect of moving from zone $i$ to zone $j$ ($i \to j$), define
#
# $$
# m_{i \to j} = \frac{\lvert FP_j - FP_i \rvert}{Z_j - Z_i},
# $$
#
# where $FP_k$ is the forgone payment at level $k$ and $Z_k$ is the number of zones at that level. The quantity $m_{i \to j}$ measures the absolute change in forgone payments per additional zone (ZMW per zone). Remove the absolute value if a signed measure is preferred.

# %%
"""
Increases in number of zones (Δ zones = destination − source)
"""

# Admin 1 (provinces) → K-means clusters
inc_1k = num_clusters - num_provinces   # additional zones when moving from provinces to clusters

# K-means clusters → Admin 2 (districts)
inc_k2 = num_districts - num_clusters   # additional zones when moving from clusters to districts

# Admin 2 (districts) → Camps
inc_2c = num_unique_camps - num_districts      # additional zones when moving from districts to camps
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
"""
Changes in forgone payments (ΔFP = destination − source; units: ZMW)
Positive ΔFP → increase in forgone payments; negative ΔFP → reduction.
"""

# Admin 1 (provinces) → K-means clusters
d_fp_1k = clusters_fp - admin_1_fp   # change when moving from provinces to clustered zones

# K-means clusters → Admin 2 (districts)
d_fp_k2 = admin_2_fp - clusters_fp   # change when moving from clusters to districts

# Admin 2 (districts) → Camps
d_fp_2c = admin_3_fp - admin_2_fp    # change when moving from districts to camps
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
"""
Marginal absolute change in forgone payments per added zone
Formula: m_{i→j} = |ΔFP_{i→j}| / ΔZ_{i→j}
Units: ZMW per added zone
Note: assumes ΔZ > 0 for each transition.
"""

# Admin 1 (provinces) → K-means clusters
marg_1k = abs(d_fp_1k) / inc_1k  

# K-means clusters → Admin 2 (districts)
marg_k2 = abs(d_fp_k2) / inc_k2  

# Admin 2 (districts) → Camps
marg_2c = abs(d_fp_2c) / inc_2c
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
print("Admin 1 to Clusters")
print("Increase in zones:", inc_1k)
print("Absolute change in forgone payments in million zambia kwacha:", round(abs(d_fp_1k)/1e6, 4))
print("Absolute change per added zone in zambia kwacha:", round(marg_1k, 2))

print("\nClusters to Admin 2")
print("Increase in zones:", inc_k2)
print("Absolute change in forgone payments in million zambia kwacha:", round(abs(d_fp_k2)/1e6, 4))
print("Absolute change per added zone in zambia kwacha:", round(marg_k2, 2))

print("\nAdmin 2 to Camps")
print("Increase in zones:", inc_2c)
print("Absolute change in forgone payments in million zambia kwacha:", round(abs(d_fp_2c)/1e6, 4))
print("Absolute change per added zone in zambia kwacha:", round(marg_2c, 2))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Admin 1 to Clusters
# Increase in zones: 19
# Absolute change in forgone payments in million zambia kwacha: 1.6379
# Absolute change per added zone in zambia kwacha: 86205.06
#
# Clusters to Admin 2
# Increase in zones: 86
# ...

# %%
vals = [round(abs(d_fp_1k)/1e6, 4), round(abs(d_fp_k2)/1e6, 4), round(abs(d_fp_2c)/1e6, 4)]
fig, ax = benefit_changes(
    vals,
    title="Total Benefit for Zone Change",
    annotate_offsets=[(0, 10), (17, -7), (-17, -4)],  # per-point placement
    annotate_ha="center",
    annotate_va="bottom",
 )
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
vals = [marg_1k, marg_k2, marg_2c]
fig, ax = benefit_changes(
    vals,
    title="Marginal Benefit per Zone Change",
    annotate_offsets=[(35, -6), (-30, -6), (3, 8)],  # per-point placement
    annotate_ha="center",
    annotate_va="bottom",
 )
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Analysis
#
# The largest marginal benefit occurs when moving from Administrative-1 to K-means clusters: increasing the number of zones from 10 to 29 reduces forgone payments by about 86,205 ZMW per added zone.
